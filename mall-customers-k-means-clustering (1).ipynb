# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px #graphing
import plotly.graph_objects as go #graphing
from plotly.subplots import make_subplots #graphing
import plotly.figure_factory as ff #graphing
import matplotlib.pyplot as plt #graphing
import seaborn as sns #graphing
from sklearn.cluster import KMeans
import os

from plotly.offline import plot, iplot, init_notebook_mode
import plotly.graph_objs as go
init_notebook_mode(connected=True)

plt.rcParams["figure.figsize"] = (12, 8)

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /kaggle/input/mall-customers/Mall_Customers.csv

# %%
df = pd.read_csv("/kaggle/input/mall-customers/Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe().style.background_gradient(cmap = "magma")
# Out:
# <style type="text/css">
# #T_bdb8e_row0_col0, #T_bdb8e_row0_col1, #T_bdb8e_row0_col2, #T_bdb8e_row0_col3, #T_bdb8e_row7_col0 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_bdb8e_row1_col0, #T_bdb8e_row5_col0 {
#   background-color: #b73779;
#   color: #f1f1f1;
# }
# #T_bdb8e_row1_col1 {
#   background-color: #20114b;
#   color: #f1f1f1;
# }
# #T_bdb8e_row1_col2, #T_bdb8e_row1_col3, #T_bdb8e_row5_col3 {
#   background-color: #4f127b;
#   color: #f1f1f1;
# }
# #T_bdb8e_row2_col0 {
#   background-color: #5f187f;
#   color: #f1f1f1;
# }
# #T_bdb8e_row2_col1, #T_bdb8e_row3_col0, #T_bdb8e_row3_col2, #T_bdb8e_row3_col3 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_bdb8e_row2_col2 {
#   background-color: #090720;
#   color: #f1f1f1;
# }
# #T_bdb8e_row2_col3 {
#   background-color: #1c1044;
#   color: #f1f1f1;
# }
# #T_bdb8e_row3_col1 {
#   background-color: #02020b;
#   color: #f1f1f1;
# }
# #T_bdb8e_row4_col0, #T_bdb8e_row5_col2 {
#   background-color: #51127c;
#   color: #f1f1f1;
# }
# #T_bdb8e_row4_col1 {
#   background-color: #0e0b2b;
#   color: #f1f1f1;
# }
# #T_bdb8e_row4_col2 {
#   background-color: #221150;
#   color: #f1f1f1;
# }
# #T_bdb8e_row4_col3 {
#   background-color: #2d1161;
#   color: #f1f1f1;
# }
# #T_bdb8e_row5_col1 {
#   background-color: #1a1042;
#   color: #f1f1f1;
# }
# #T_bdb8e_row6_col0 {
#   background-color: #fc8961;
#   color: #f1f1f1;
# }
# #T_bdb8e_row6_col1 {
#   background-color: #36106b;
#   color: #f1f1f1;
# }
# #T_bdb8e_row6_col2 {
#   background-color: #752181;
#   color: #f1f1f1;
# }
# #T_bdb8e_row6_col3 {
#   background-color: #7c2382;
#   color: #f1f1f1;
# }
# #T_bdb8e_row7_col1 {
#   background-color: #651a80;
#   color: #f1f1f1;
# }
# #T_bdb8e_row7_col2 {
#   background-color: #ef5d5e;
#   color: #f1f1f1;
# }
# #T_bdb8e_row7_col3 {
#   background-color: #b3367a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bdb8e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CustomerID</th>
#       <th class="col_heading level0 col1" >Age</th>
#       <th class="col_heading level0 col2" >Annual Income (k$)</th>
#       <th class="col_heading level0 col3" >Spending Score (1-100)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdb8e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_bdb8e_row0_col0" class="data row0 col0" >200.000000</td>
#       <td id="T_bdb8e_row0_col1" class="data row0 col1" >200.000000</td>
#       <td id="T_bdb8e_row0_col2" class="data row0 col2" >200.000000</td>
#       <td id="T_bdb8e_row0_col3" class="data row0 col3" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdb8e_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_bdb8e_row1_col0" class="data row1 col0" >100.500000</td>
#       <td id="T_bdb8e_row1_col1" class="data row1 col1" >38.850000</td>
#       <td id="T_bdb8e_row1_col2" class="data row1 col2" >60.560000</td>
#       <td id="T_bdb8e_row1_col3" class="data row1 col3" >50.200000</td>
#     </tr>
#     <tr>
#       <th id="T_bdb8e_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_bdb8e_row2_col0" class="data row2 col0" >57.879185</td>
#       <td id="T_bdb8e_row2_col1" class="data row2 col1" >13.969007</td>
#       <td id="T_bdb8e_row2_col2" class="data row2 col2" >26.264721</td>
#       <td id="T_bdb8e_row2_col3" class="data row2 col3" >25.823522</td>
#     </tr>
#     <tr>
#       <th id="T_bdb8e_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_bdb8e_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_bdb8e_row3_col1" class="data row3 col1" >18.000000</td>
#       <td id="T_bdb8e_row3_col2" class="data row3 col2" >15.000000</td>
#       <td id="T_bdb8e_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdb8e_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_bdb8e_row4_col0" class="data row4 col0" >50.750000</td>
#       <td id="T_bdb8e_row4_col1" class="data row4 col1" >28.750000</td>
#       <td id="T_bdb8e_row4_col2" class="data row4 col2" >41.500000</td>
#       <td id="T_bdb8e_row4_col3" class="data row4 col3" >34.750000</td>
#     </tr>
#     <tr>
#       <th id="T_bdb8e_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_bdb8e_row5_col0" class="data row5 col0" >100.500000</td>
#       <td id="T_bdb8e_row5_col1" class="data row5 col1" >36.000000</td>
#       <td id="T_bdb8e_row5_col2" class="data row5 col2" >61.500000</td>
#       <td id="T_bdb8e_row5_col3" class="data row5 col3" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdb8e_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_bdb8e_row6_col0" class="data row6 col0" >150.250000</td>
#       <td id="T_bdb8e_row6_col1" class="data row6 col1" >49.000000</td>
#       <td id="T_bdb8e_row6_col2" class="data row6 col2" >78.000000</td>
#       <td id="T_bdb8e_row6_col3" class="data row6 col3" >73.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdb8e_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_bdb8e_row7_col0" class="data row7 col0" >200.000000</td>
#       <td id="T_bdb8e_row7_col1" class="data row7 col1" >70.000000</td>
#       <td id="T_bdb8e_row7_col2" class="data row7 col2" >137.000000</td>
#       <td id="T_bdb8e_row7_col3" class="data row7 col3" >99.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.pie(df, names = "Genre", color = "Genre", title = "Gender Distribution",
             color_discrete_sequence = ["#0044FF", "#DE00FF"])

fig.update_traces(textinfo = "value", textfont_size = 20,
                  marker = dict(line = dict(color = "#FFFFFF", width = 2)))

fig.update_layout(template = "plotly_dark", font = dict(family = "PT Sans", size = 20))
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_7.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.box(df, y = "Annual Income (k$)", color = "Genre",
             points = "all", notched = True,
             color_discrete_sequence = ["#0044FF", "#DE00FF"],
             title = "Male and Female Annual Income (k$)")

fig.update_traces(marker = dict(size = 5, symbol = "circle-open"))
fig.update_traces(fillcolor = "#000000")
fig.update_layout(template = "plotly_dark")

fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_8.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Annual Income (k$) & Spending Score (1-100) by Age 18 - 38

# %%
fig = px.box(df, x = "Age",  y = ["Annual Income (k$)", "Spending Score (1-100)"], color = "variable",
             range_x = (17, 38), color_discrete_sequence = ["#00C700", "#FF0000"],
             title = "Annual Income (k$) & Spending Score (1-100) by Age 18 - 38")

fig.update_layout(template = "plotly_dark", font = dict(family = "PT Sans", size = 20, color = "#97FFFF"))
fig.update_traces(marker = dict(size = 5, line = dict(width = 1, color = "#FFFFFF")))

fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_9.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Annual Income (k$) & Spending Score (1-100) by Age 38 - 70

# %%
fig = px.box(df, x = "Age",  y = ["Annual Income (k$)", "Spending Score (1-100)"], color = "variable",
             range_x = (38, 71), color_discrete_sequence = ["#00C700", "#FF0000"],
             title = "Annual Income (k$) & Spending Score (1-100) by Age 38 - 70")

fig.update_layout(template = "plotly_dark", font = dict(family = "PT Sans", size = 20, color = "#97FFFF"))
fig.update_traces(marker = dict(size = 5, line = dict(width = 1, color = "#FFFFFF")))

fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_10.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Annual Income (k$) & Spending Score (1-100) by Age

# %%
fig = px.scatter(df, x = "Age",  y = ["Annual Income (k$)", "Spending Score (1-100)"], color = "variable",
                 color_discrete_sequence = ["#00C700", "#FF0000"],
                 title = "Annual Income (k$) & Spending Score (1-100) by Age")

fig.update_layout(template = "plotly_dark", font = dict(family = "PT Sans", size = 20, color = "#97FFFF"))
fig.update_traces(marker = dict(size = 5, line = dict(width = 1, color = "#FFFFFF")))

fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig = px.scatter(df, x = "Age",  y = ["Annual Income (k$)", "Spending Score (1-100)"], color = "Genre",
                 color_discrete_sequence = ["#0044FF", "#DE00FF"],
                 title = "Annual Income (k$) & Spending Score (1-100) by Age")

fig.update_layout(template = "plotly_dark", font = dict(family = "PT Sans", size = 20, color = "#97FFFF"))
fig.update_traces(marker = dict(size = 5, line = dict(width = 1, color = "#FFFFFF")))

fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_12.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Male and Female 💵 Spending Score, Annual Income, Age

# %%
fig = px.scatter_3d(df, x = "Spending Score (1-100)", y = "Annual Income (k$)", z = "Age",
                        hover_data = ["Age"], color = "Genre", opacity = 0.8,
                        title = f"Male and Female Mall Customers  💵  Spending Score,  Annual Income,  Age",
                        color_discrete_sequence = ["#0044FF", "#DE00FF"])

fig.update_traces(marker = dict(size = 3, line = dict(width = 1, color = "#FFFFFF")))
fig.update_coloraxes(showscale = False)
fig.update_layout(template = "plotly_dark", font = dict(family = "PT Sans", size = 12, color = "#97FFFF"))
fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_13.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
df0 = df.drop(columns = "Genre")

# %% [markdown]
# # K-Means Clustering (2-10) Spending Score, Annual Income, Age

# %%
for clusters in range (2, 11):    
    kms = KMeans(n_clusters = clusters, init = "k-means++")
    kcluster = pd.DataFrame(kms.fit_predict(df0), columns = ["kcluster"])
    df0["cluster"] = kcluster

    fig = px.scatter_3d(df0, x = "Spending Score (1-100)", y = "Annual Income (k$)", z = "Age",
                        hover_data = ["Age"], color = "cluster", opacity = 0.8,
                        title = f"K-Means Clustering Mall Customers 💵 (Clusters = {clusters})  Spending Score,  Annual Income,  Age",
                        color_continuous_scale = ["#FF0000", "#0000FF", "#FFFF00", 
                                                  "#00EFFF", "#FF00FF", "#FFFFFF"])

    fig.update_traces(marker = dict(size = 3, line = dict(width = 1, color = "#FFFFFF")))
    fig.update_coloraxes(showscale = False)
    fig.update_layout(template = "plotly_dark", font = dict(family = "PT Sans", size = 12, color = "#97FFFF"))
    fig.show(renderer="iframe")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# **Thank you for viewing this notebook. Please feel free to provide any feedback!**
